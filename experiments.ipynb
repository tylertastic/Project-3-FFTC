# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [30, 330]
y = [190, 190]

# %%
x[0] = 31
x
# Out:
# [31, 330]

# %%
plt.plot(x, y)
plt.show()

# %%
level = 3
x = [0]*level
x
# Out:
# [0, 0, 0]

# %%
xL = np.array([[0]*(level-1), 30]).flatten()

# %%
xL
# Out:
# array([list([0, 0, 0, 0, 0, 0, 0, 0, 0]), 30], dtype=object)

# %%
xL = [[0]*(level-1), 30]
xL
# Out:
# [[0, 0], 30]

# %%
len(xL[0])
# Out:
# 9

# %%
max_lvl = 0
xL = [item for sublist in [[0]*(max_lvl-1),[30]] for item in sublist]

# %%
xL
# Out:
# [30]

# %%
[0]*0
# Out:
# []

# %%
[0]*-1
# Out:
# []

# %%
plt.plot([30, 130], [190, 190])
plt.plot([180, 180], [190, 190])
plt.show()

# %%
plt.plot([0,1],[0,0])
plt.xlim(0, 1)
plt.ylim(-1, 5)
plt.show()

# %%
a = np.array([0,1])
(1/3)*a
# Out:
# array([0.        , 0.33333333])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
root(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-175ad987cf43> in <module>
# ----> 1 root(3)
#
# NameError: name 'root' is not defined

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %%
np.array([[1,0],[0,1]])+np.array([[1,0],[0,1]])
# Out:
# array([[2, 0],
#        [0, 2]])

# %%
initiator = np.array([[0,1],[0,0]])

# %%
plt.plot(initiator[0], initiator[1])

# %%
def f():
    return plt.plot([0,1],[1,1])

# %%
2*f()

# %%
a = np.array([[1,2],
             [3,4]])
b = np.array([[5,6],
             [7,8]])
np.concatenate((a,b))
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
np.concatenate((a,b), axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
np.concatenate((a,b), axis=1)
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %%
c = np.array([[0,0],[0,0]])

# %%
c+a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
d = np.array([[[0,0],[0,0]]])

# %%
d[0]
# Out:
# array([[0, 0],
#        [0, 0]])

# %%
d[0] = [[1,1],[1,1]]
d
# Out:
# array([[[1, 1],
#         [1, 1]]])

# %%
plt.plot([0,1],[0,0])
plt.plot([0,1],[1,1])
plt.show()

# %%
initiator = [[0,1],[0,0]]
a = []

# %%
a.append(np.array(initiator))
np.array(a)
# Out:
# array([[[0, 1],
#         [0, 0]]])
